# %%
import numpy as np
import networkx as nx
from networkx import DiGraph
import matplotlib.pyplot as plt
import pickle

# %%
G = pickle.load(open('graphs/graph_00001.pickle', 'rb'))

# %%
nx.draw(G)
